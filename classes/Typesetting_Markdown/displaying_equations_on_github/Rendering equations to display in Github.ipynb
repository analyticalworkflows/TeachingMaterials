# %% [markdown]
# Below is some math I would like to display. I will first experiment with formatting, by creating a line break before the equation
#
# $p_i = \sum_j p_{ij} p_{ji}$
#
# which will provide a proof of concept for a paragraph that contains math.

# %% [markdown]
# I will now present a histogram of
#
# $X \sim Norm(0, 1)$
#
# which will add some R code to the demo.

# %%
X <- rnorm(1000, 0,1)
hist(X, xlab = "A random variable", ylab = "Its frequency")
# Out:
# Plot with title “Histogram of X”
